# %%
import matplotlib.pyplot as plt
import laspy
import tensorflow as tf 
import numpy as np
import pandas as pd

# %%
las = laspy.read('dataset/6.las')
las2 = laspy.read('dataset/7.las')
# las.points = las.points[las.classification == 2]
# las

# %%
las.X, las.Y, las.Z
# Out:
# (array([-7523, -7524, -7524, ..., 21926, 21597, 21579]),
#  array([ -2387,  -2383,  -2378, ..., -12246, -13144, -13150]),
#  array([4809, 4805, 4800, ..., 4271, 5244, 5256]))

# %%
# fig = plt.figure(figsize=(5, 5))
# ax = fig.add_subplot(111, projection='3d')
# ax.scatter(las.X, las.Y, las.Z)
# ax.set_axis_off()
# plt.show()

fig = plt.figure(figsize=(5, 5))
ax = plt.axes(projection='3d')
ax.scatter(las.X, las.Y, las.Z)
# ax.set_axis_off()
plt.show()

# %%
fig = plt.figure(figsize=(5, 5))
ax = plt.axes(projection='3d')
ax.scatter(las2.X, las2.Y, las2.Z)
# ax.set_axis_off()
plt.show()

# %%
# for p in las.points:
#     print(p)

# plt.hist(las.intensity)
# Out:
# (array([4.645233e+06, 5.595230e+05, 6.891800e+04, 1.026100e+04,
#         3.708000e+03, 9.711000e+03, 1.140800e+04, 4.280000e+02,
#         4.110000e+02, 4.290000e+02]),
#  array([    0.,  6528., 13056., 19584., 26112., 32640., 39168., 45696.,
#         52224., 58752., 65280.]),
#  <BarContainer object of 10 artists>)

# %%
# las.x, las.y.shape, las.z.shape
# print(las)
# las[:, 0].format 
# print(np.unique(las.classification))
# plt.imshow(las)

import laspy

fs = s3fs.S3FileSystem()
with fs.open('dataset/6.las', 'rb') as f:
     if f.header.point_count < 100_000_000:
         las = laspy.read(f)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# d:\Workspace\python\iset_2022\train.ipynb Cell 3' in <cell line: 10>()
#       <a href='vscode-notebook-cell:/d%3A/Workspace/python/iset_2022/train.ipynb#ch0000002?line=6'>7</a> import laspy
#       <a href='vscode-notebook-cell:/d%3A/Workspace/python/iset_2022/train.ipynb#ch0000002?line=8'>9</a> fs = s3fs.S3FileSystem()
# ---> <a href='vscode-notebook-cell:/d%3A/Workspace/python/iset_2022/train.ipynb#ch0000002?line=9'>10</a> with fs.open('dataset/6.las', 'rb') as f:
#      <a href='vscode-notebook-cell:/d%3A/Workspace/python/iset_2022/train.ipynb#ch0000002?line=10'>11</a>      if f.header.point_count < 100_000_000:
#      <a href='vscode-notebook-cell:/d%3A/Workspace/python/iset_2022/train.ipynb#ch0000002?line=11'>12</a>          las = laspy.read(f)
#
# ...
